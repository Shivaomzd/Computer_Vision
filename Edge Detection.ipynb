# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

img = cv2.imread('H:\project\Sample photo.jpg' , 1)
edge_img = cv2.Canny(img , 10 , 255)
plt.imshow(cv2.cvtColor(edge_img , cv2.COLOR_BGR2RGB))
plt.show()
